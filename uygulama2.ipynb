# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('banka.csv')
df=df[['sorgu','label']]
stopwords=['fakat','lakin','ancak','acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha', 'de', 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç', 'için', 'ile', 'ise', 'kez', 'ki', 'kim', 'mı', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey', 'siz', 'şu', 'tüm', 've', 'veya', 'ya', 'yani']

mesaj=input("Yapmak İstediniz İşlemi Giriniz.")

mesajdf=pd.DataFrame({"sorgu":mesaj,"label":0},index=[42])

df=pd.concat([df,mesajdf],ignore_index=True)



for word in stopwords:
    word=" "+word+" "
    df['sorgu']=df['sorgu'].str.replace(word," ")

cv=CountVectorizer(max_features=50)


x=cv.fit_transform(df['sorgu']).toarray()
y=df['label']


tahmin=x[-1].copy()  #vektörleştirilmiş veri elemanının son elemanını seçer

x=x[0:-1]  #burada verileirimizden son eklenen değeri yani bizim eklediğimiz değeri çıkarıyoruz.
y=y[0:-1]

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=21,train_size=0.7)

rf=RandomForestClassifier()
model=rf.fit(x_train,y_train)
skor=model.score(x_test,y_test)

sonuc=model.predict([tahmin])

print("Sonuc:",sonuc,"Skor:",skor)
# Out:
# Yapmak İstediniz İşlemi Giriniz.kartımı evde mi unuttum bilmiyorum
# Sonuc: ['kartkayip'] Skor: 1.0

# %%
df.head(45)
# Out:
#                                              sorgu      label
# 0                          kredi kartımı kaybettim  kartkayip
# 1                          banka kartımı kaybettim  kartkayip
# 2                        kredi kartımı bulamıyorum  kartkayip
# 3                             kredi kartım çalındı  kartkayip
# 4               kredi kartımın olduğunu bilmiyorum  kartkayip
# 5             kredi kartımın olduğu çüzdan çalındı  kartkayip
# 6                            kredi kartım kayboldu  kartkayip
# 7                            banka kartım kayboldu  kartkayip
# 8                        banka kartımı bulamıyorum  kartkayip
# 9                             banka kartım çalındı  kartkayip
# 10              banka kartımın olduğunu bilmiyorum  kartkayip
# 11            banka kartımın olduğu cüzdan çalındı  kartkayip
# 12                           banka kartım kayboldu  kartkayip
# 13                           kredi kartımı unuttum  kartkayip
# 14                           banka kartımı unuttum  kartkayip
# 15                          kredi kartımı arıyorum  kartkayip
# 16                          banka kartımı arıyorum  kartkayip
# 17                       kredi kartımı bulamıyorum  kartkayip
# 18                       banka kartımı bulamıyorum  kartkayip
# 19              kredi kartımı kaybetmiş olabilirim  kartkayip
# 20              banka kartımı kaybetmiş olabilirim  kartkayip
# 21                  kredi kartım çalınmış olabilir  kartkayip
# 22                  banka kartım çalınmış olabilir  kartkayip
# 23            kredi kartımın yerini hatırlamıyorum  kartkayip
# 24            banka kartımın yerini hatırlamıyorum  kartkayip
# 25                   kredi kartımın yerini unuttum  kartkayip
# 26                   banka kartımın yerini unuttum  kartkayip
# 27               kredi kartımın yerini bulamıyorum  kartkayip
# 28               banka kartımın yerini bulamıyorum  kartkayip
# 29                         kredi kartımı çaldırdım  kartkayip
# 30                         banka kartımı çaldırdım  kartkayip
# 31  kredi kartımı bulamıyorum yardım eder misiniz   kartkayip
# 32  banka kartımı bulamıyorum yardım eder misiniz   kartkayip
# 33         kredi kartımın kaybolduğunu düşünüyorum  kartkayip
# 34         banka kartımın kaybolduğunu düşünüyorum  kartkayip
# 35                kredi kartımı bulmak yapmalıyım   kartkayip
# 36                banka kartımı bulmak yapmalıyım   kartkayip
# 37      kredi kartımın kaybolduğunu bildirmeliyim   kartkayip
# 38      banka kartımın kaybolduğunu bildirmeliyim   kartkayip
# 39             kredi kartımı çaldırdım yapmalıyım   kartkayip
# 40             banka kartımı çaldırdım yapmalıyım   kartkayip
# 41             kredi kartımın çalındığını anlarım   kartkayip
# 42             banka kartımın çalındığını anlarım   kartkayip
# 43        kredi kartımın çalındığını rapor ederim   kartkayip
# 44        banka kartımın çalındığını rapor ederim   kartkayip
